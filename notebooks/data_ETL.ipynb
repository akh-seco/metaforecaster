# %% [markdown]
# This is a notebook for the data ETL for the metaforecaster model

# %%
import pandas as pd

# %% [markdown]
# Cell in SQL

# %%
# %sql
SELECT * FROM work_days_per_month
# Out:
# Running cells with 'base (Python 3.13.12)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n base ipykernel --update-deps --force-reinstall'
